# %%
import blitzgsea as blitz
import openai
from pathlib import Path
import json
from gseaai import GSEAAI
client = openai.OpenAI()
gsea_ai = GSEAAI(client)

# %%
import re

def clean_elements(array):
    cleaned_array = []
    for element in array:
        # Use regular expression to remove (GO:xxx) substring,  R-HSA-xxx substrings, and WPxxx substrings
        cleaned_element = re.sub(r'\s*\(GO:\d+\)\s*|\s*R-HSA-\d+\s*|\s*WP\d+\s*', '', element)
        cleaned_array.append(cleaned_element)
    return cleaned_array

# %%
lib_names = ["KEGG_2019", "GO_Biological_Process_2018"]
lib_names = ["GO_Biological_Process_2018"]

# %%
for lib_name in lib_names:
    lib = blitz.enrichr.read_gmt("libs_yeast/gmt/" + lib_name + ".txt")
    print(len(lib))
# Out:
# 1649

# %%
yeast_libs = {}
for lib_name in lib_names:
    lib = blitz.enrichr.read_gmt("libs_yeast/gmt/" + lib_name + ".txt")
    lib = dict(zip(clean_elements(list(lib.keys())), lib.values()))
    json.dump(lib, open("libs_yeast/yeast/" + lib_name + '.json', 'w'), indent=4)
    yeast_libs[lib_name] = lib

# %%
aclient = openai.AsyncClient()
models = ["gpt-3.5-turbo-0125", "gpt-4o-2024-05-13"]
for model in models:
    for lib_name in lib_names:
        lib = yeast_libs[lib_name]
        ai_lib_json = Path("libs_yeast/" + model + "/" + lib_name + '.json')
        if not ai_lib_json.is_file():
            ai_lib = await gsea_ai.get_genes(aclient, list(lib.keys()), modelg=model, species="yeast")
            json.dump(ai_lib, open(str(ai_lib_json), 'w'), indent=4)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1649/1649 [01:14<00:00, 22.00it/s]
# warning: genes in MAPK cascade are not unique
# warning: genes in inactivation of MAPK activity are not unique
# warning: genes in protein homooligomerization are not unique
# warning: genes in protein import into nucleus are not unique
# warning: genes in positive regulation of protein localization to nucleus are not unique
# warning: genes in DNA recombination are not unique
# warning: genes in telomere maintenance are not unique
# warning: genes in mRNA export from nucleus are not unique
# warning: genes in fungal-type cell wall organization are not unique
# warning: genes in mitochondrial translation are not unique
# warning: genes in ribosome biogenesis are not unique
# warning: genes in actin filament bundle assembly are not unique
# warning: genes in phospholipid transport are not unique
# warning: genes in mitochondrial respiratory chain complex assembly are not unique
# warning: genes in protein import into mitochondrial inner membrane are not unique
# warning: genes in proteasome-mediated ubiquitin-dependent protein catabolic process are not unique
# warning: genes in proteasome assembly are not unique
# warning: genes in regulation of cell cycle are not unique
# warning: genes in ethanol metabolic process are not unique
# warning: genes in gluconeogenesis are not unique
# warning: genes in cellular response to oxidative stress are not unique
# warning: genes in cellular copper ion homeostasis are not unique
# warning: genes in protein localization to nucleus are not unique
# warning: genes in negative regulation of mitotic cell cycle are not unique
# warning: genes in positive regulation of mitotic cell cycle are not unique
# warning: genes in pyruvate metabolic process are not unique
# warning: genes in sucrose catabolic process are not unique
# warning: genes in regulation of vacuole fusion, non-autophagic are not unique
# warning: genes in negative regulation of ATPase activity are not unique
# warning: genes in protein localization to bud neck are not unique
# warning: genes in positive regulation of transcription by galactose are not unique
# warning: genes in endocytic recycling are not unique
# warning: genes in early endosome to Golgi transport are not unique
# warning: genes in regulation of endoplasmic reticulum unfolded protein response are not unique
# warning: genes in mitotic sister chromatid segregation are not unique
# warning: genes in homologous chromosome segregation are not unique
# warning: genes in protein targeting to mitochondrion are not unique
# warning: genes in RNA splicing are not unique
# warning: genes in Group I intron splicing are not unique
# warning: genes in mRNA processing are not unique
# warning: genes in transcription from RNA polymerase II promoter are not unique
# warning: genes in tRNA transcription from RNA polymerase III promoter are not unique
# warning: genes in galactose metabolic process are not unique
# warning: genes in ribosomal large subunit assembly are not unique
# warning: genes in heme biosynthetic process are not unique
# warning: genes in regulation of mitotic recombination are not unique
# warning: genes in regulation of transcription from RNA polymerase II promoter are not unique
# warning: genes in basic amino acid transport are not unique
# warning: genes in transmembrane transport are not unique
# warning: genes in lagging strand elongation are not unique
# warning: genes in ion transport are not unique
# warning: genes in DNA repair are not unique
# warning: genes in nuclear-transcribed mRNA catabolic process, deadenylation-dependent decay are not unique
# warning: genes in translational termination are not unique
# warning: genes in ribosomal small subunit export from nucleus are not unique
# warning: genes in nuclear-transcribed mRNA poly(A) tail shortening are not unique
# warning: genes in deadenylation-dependent decapping of nuclear-transcribed mRNA are not unique
# warning: genes in protein ubiquitination are not unique
# warning: genes in deadenylation-independent decapping of nuclear-transcribed mRNA are not unique
# warning: genes in double-strand break repair via homologous recombination are not unique
# warning: genes in branched-chain amino acid biosynthetic process are not unique
# warning: genes in tryptophan catabolic process are not unique
# warning: genes in glycolytic fermentation to ethanol are not unique
# warning: genes in phosphatidylinositol biosynthetic process are not unique
# warning: genes in double-strand break repair via break-induced replication are not unique
# warning: genes in spliceosomal complex disassembly are not unique
# warning: genes in regulation of kinase activity are not unique
# warning: genes in carbon catabolite activation of transcription from RNA polymerase II promoter are not unique
# warning: genes in cAMP-mediated signaling are not unique
# warning: genes in DNA amplification are not unique
# warning: genes in DNA recombinase assembly are not unique
# warning: genes in DNA strand renaturation are not unique
# warning: genes in double-strand break repair via single-strand annealing are not unique
# warning: genes in cellular protein localization are not unique
# warning: genes in small GTPase mediated signal transduction are not unique
# warning: genes in actin cytoskeleton reorganization are not unique
# warning: genes in actin filament organization are not unique
# warning: genes in response to unfolded protein are not unique
# warning: genes in nucleotide metabolic process are not unique
# warning: genes in negative regulation of chromatin silencing are not unique
# warning: genes in phosphatidylinositol phosphorylation are not unique
# warning: genes in positive regulation of mitochondrial translation are not unique
# warning: genes in nuclear-transcribed mRNA catabolic process, nonsense-mediated decay are not unique
# warning: genes in nucleosome organization are not unique
# warning: genes in positive regulation of ribosomal protein gene transcription from RNA polymerase II promoter are not unique
# warning: genes in cellular response to starvation are not unique
# warning: genes in chromatin remodeling are not unique
# warning: genes in transcription elongation from RNA polymerase I promoter are not unique
# warning: genes in transcription from RNA polymerase III promoter are not unique
# warning: genes in ergosterol biosynthetic process are not unique
# warning: genes in negative regulation of Ras protein signal transduction are not unique
# warning: genes in ribosomal small subunit biogenesis are not unique
# warning: genes in protein targeting to ER are not unique
# warning: genes in vesicle fusion are not unique
# warning: genes in lysine biosynthetic process via aminoadipic acid are not unique
# warning: genes in G2/M transition of mitotic cell cycle are not unique
# warning: genes in SCF-dependent proteasomal ubiquitin-dependent protein catabolic process are not unique
# warning: genes in regulation of exit from mitosis are not unique
# warning: genes in ornithine metabolic process are not unique
# warning: genes in cellular response to heat are not unique
# warning: genes in sulfur amino acid metabolic process are not unique
# warning: genes in homoserine metabolic process are not unique
# warning: genes in regulation of translation are not unique
# warning: genes in inositol lipid-mediated signaling are not unique
# warning: genes in adenylate cyclase-modulating G-protein coupled receptor signaling pathway are not unique
# warning: genes in rRNA processing are not unique
# warning: genes in regulation of DNA-dependent DNA replication initiation are not unique
# warning: genes in SRP-dependent cotranslational protein targeting to membrane, translocation are not unique
# warning: genes in DNA-dependent DNA replication are not unique
# warning: genes in ATP-dependent chromatin remodeling are not unique
# warning: genes in tRNA splicing, via endonucleolytic cleavage and ligation are not unique
# warning: genes in spliceosomal complex assembly are not unique
# warning: genes in protein transport to vacuole involved in ubiquitin-dependent protein catabolic process via the multivesicular body sorting pathway are not unique
# warning: genes in maturation of LSU-rRNA from tricistronic rRNA transcript (SSU-rRNA, 5.8S rRNA, LSU-rRNA) are not unique
# warning: genes in threonine biosynthetic process are not unique
# warning: genes in negative regulation of meiotic nuclear division are not unique
# warning: genes in cellular bud site selection are not unique
# warning: genes in septin ring organization are not unique
# warning: genes in protein dephosphorylation are not unique
# warning: genes in DNA replication-independent nucleosome organization are not unique
# 'gene'
# RNA polymerase II transcriptional preinitiation complex assembly
# ```json
# [
#     {"gene": "TFIIA"},
#     {"gene": "TFIIB"},
#     {"gene": "TFIID"},
#     {"genes": [
#         {"gene": "TAF1"},
#         {"gene": "TAF2"},
#         {"gene": "TAF3"},
#         {"gene": "TAF4"},
#         {"gene": "TAF5"},
#         {"gene": "TAF6"},
#         {"gene": "TAF7"},
#         {"gene": "TAF9"},
#         {"gene": "TAF10"},
#         {"gene": "TAF11"},
#         {"gene": "TAF12"},
#         {"gene": "TAF13"}
#     ]},
#     {"gene": "TFIIE"},
#     {"gene": "TFIIF"},
#     {"gene": "TFIIH"}
# ]
# ```
# warning: genes in RNA polymerase III transcriptional preinitiation complex assembly are not unique
# warning: genes in RNA import into nucleus are not unique
# warning: genes in tRNA export from nucleus are not unique
# warning: genes in regulation of transcription from RNA polymerase II promoter in response to oxidative stress are not unique
# warning: genes in positive regulation of transcription from RNA polymerase I promoter are not unique
# warning: genes in telomere maintenance via telomere lengthening are not unique
# warning: genes in cellular potassium ion homeostasis are not unique
# warning: genes in protein autophosphorylation are not unique
# warning: genes in double-strand break repair via nonhomologous end joining are not unique
# warning: genes in Golgi to endosome transport are not unique
# warning: genes in histone ubiquitination are not unique
# warning: genes in late endosome to vacuole transport are not unique
# warning: genes in regulation of DNA recombination are not unique
# warning: genes in mitotic sister chromatid cohesion are not unique
# warning: genes in positive regulation of transcription from RNA polymerase II promoter by pheromones are not unique
# warning: genes in calcium ion transport are not unique
# warning: genes in cellular calcium ion homeostasis are not unique
# warning: genes in response to salt stress are not unique
# warning: genes in fatty acid beta-oxidation are not unique
# warning: genes in bipolar cellular bud site selection are not unique
# warning: genes in phospholipid biosynthetic process are not unique
# warning: genes in protein import into mitochondrial outer membrane are not unique
# warning: genes in mitochondrial outer membrane translocase complex assembly are not unique
# warning: genes in chromatin assembly are not unique
# warning: genes in DNA damage checkpoint are not unique
# warning: genes in intra-S DNA damage checkpoint are not unique
# warning: genes in fungal-type cell wall chitin biosynthetic process are not unique
# warning: genes in SRP-dependent cotranslational protein targeting to membrane are not unique
# warning: genes in posttranslational protein targeting to endoplasmic reticulum membrane are not unique
# warning: genes in posttranslational protein targeting to membrane, translocation are not unique
# warning: genes in nucleosome positioning are not unique
# warning: genes in signal peptide processing are not unique
# warning: genes in rRNA methylation are not unique
# warning: genes in regulation of transcription from RNA polymerase I promoter are not unique
# warning: genes in sulfate assimilation are not unique
# warning: genes in establishment of mitotic sister chromatid cohesion are not unique
# warning: genes in actin cortical patch assembly are not unique
# warning: genes in generation of catalytic spliceosome for second transesterification step are not unique
# warning: genes in protein retention in ER lumen are not unique
# warning: genes in fungal-type cell wall beta-glucan biosynthetic process are not unique
# warning: genes in histone exchange are not unique
# warning: genes in vacuolar proton-transporting V-type ATPase complex assembly are not unique
# warning: genes in regulation of mitotic spindle organization are not unique
# warning: genes in negative regulation of Rho protein signal transduction are not unique
# warning: genes in regulation of reciprocal meiotic recombination are not unique
# warning: genes in regulation of establishment or maintenance of cell polarity are not unique
# warning: genes in isoleucine metabolic process are not unique
# warning: genes in nuclear-transcribed mRNA catabolic process, 3'-5' exonucleolytic nonsense-mediated decay are not unique
# warning: genes in transcription initiation from RNA polymerase III promoter are not unique
# warning: genes in nuclear envelope organization are not unique
# warning: genes in protein processing are not unique
# warning: genes in cellular response to hydrogen peroxide are not unique
# warning: genes in cellular response to cold are not unique
# warning: genes in cellular response to osmotic stress are not unique
# warning: genes in peroxisome inheritance are not unique
# warning: genes in phosphorylated carbohydrate dephosphorylation are not unique
# warning: genes in chaperone-mediated protein complex assembly are not unique
# warning: genes in generation of catalytic spliceosome for first transesterification step are not unique
# warning: genes in protein targeting to membrane are not unique
# warning: genes in mRNA export from nucleus in response to heat stress are not unique
# warning: genes in positive regulation of translational initiation are not unique
# warning: genes in phosphatidylethanolamine biosynthetic process are not unique
# warning: genes in regulation of mitotic cell cycle are not unique
# warning: genes in tRNA wobble uridine modification are not unique
# warning: genes in dephosphorylation are not unique
# warning: genes in TOR signaling are not unique
# warning: genes in vesicle organization are not unique
# warning: genes in regulation of meiotic nuclear division are not unique
# warning: genes in negative regulation of transcription from RNA polymerase I promoter are not unique
# warning: genes in cellular iron ion homeostasis are not unique
# warning: genes in transcriptional start site selection at RNA polymerase II promoter are not unique
# warning: genes in peroxisome fission are not unique
# warning: genes in mitotic DNA replication checkpoint are not unique
# warning: genes in protein import into peroxisome matrix are not unique
# warning: genes in mitochondrial translational initiation are not unique
# warning: genes in nuclear-transcribed mRNA catabolic process are not unique
# warning: genes in nuclear division are not unique
# warning: genes in autophagy of peroxisome are not unique
# warning: genes in regulation of transcription involved in G2/M transition of mitotic cell cycle are not unique
# warning: genes in oligosaccharide catabolic process are not unique
# warning: genes in plasma membrane organization are not unique
# warning: genes in positive regulation of actin cytoskeleton reorganization are not unique
# warning: genes in cell morphogenesis are not unique
# warning: genes in response to glucose are not unique
# warning: genes in transcription, DNA-templated are not unique
# warning: genes in glycogen biosynthetic process are not unique
# warning: genes in mRNA 5'-splice site recognition are not unique
# warning: genes in sphingolipid biosynthetic process are not unique
# warning: genes in iron-sulfur cluster assembly are not unique
# warning: genes in osmosensory signaling pathway via Sho1 osmosensor are not unique
# warning: genes in mitotic spindle assembly checkpoint are not unique
# warning: genes in nucleosome assembly are not unique
# warning: genes in protein localization to chromosome, centromeric region are not unique
# warning: genes in copper ion transport are not unique
# warning: genes in nuclear polyadenylation-dependent mRNA catabolic process are not unique
# warning: genes in cellular response to methylmercury are not unique
# warning: genes in nucleosome disassembly are not unique
# warning: genes in positive regulation of microtubule polymerization are not unique
# warning: genes in polyphosphate metabolic process are not unique
# warning: genes in phosphate ion transport are not unique
# warning: genes in pre-mRNA cleavage required for polyadenylation are not unique
# warning: genes in protein lipoylation are not unique
# warning: genes in septin ring assembly are not unique
# warning: genes in intracellular protein transport are not unique
# warning: genes in late endosome to vacuole transport via multivesicular body sorting pathway are not unique
# warning: genes in exonucleolytic trimming to generate mature 3'-end of 5.8S rRNA from tricistronic rRNA transcript (SSU-rRNA, 5.8S rRNA, LSU-rRNA) are not unique
# warning: genes in ncRNA 3'-end processing are not unique
# warning: genes in nuclear polyadenylation-dependent rRNA catabolic process are not unique
# warning: genes in nuclear polyadenylation-dependent tRNA catabolic process are not unique
# warning: genes in thiamine metabolic process are not unique
# warning: genes in nuclear mRNA surveillance are not unique
# warning: genes in lipid particle organization are not unique
# warning: genes in DNA double-strand break processing are not unique
# warning: genes in mitotic spindle assembly are not unique
# warning: genes in ATP export are not unique
# warning: genes in protein maturation by iron-sulfur cluster transfer are not unique
# warning: genes in cellular manganese ion homeostasis are not unique
# warning: genes in sterol metabolic process are not unique
# warning: genes in endonucleolytic cleavage to generate mature 5'-end of SSU-rRNA from (SSU-rRNA, 5.8S rRNA, LSU-rRNA) are not unique
# warning: genes in cytoplasmic mRNA processing body assembly are not unique
# warning: genes in retrograde protein transport, ER to cytosol are not unique
# warning: genes in sister chromatid biorientation are not unique
# warning: genes in ER-associated misfolded protein catabolic process are not unique
# warning: genes in regulation of formin-nucleated actin cable assembly are not unique
# warning: genes in protein O-linked glycosylation are not unique
# warning: genes in nuclear-transcribed mRNA catabolic process, endonucleolytic cleavage-dependent decay are not unique
# warning: genes in glycogen metabolic process are not unique
# warning: genes in pyrimidine nucleobase biosynthetic process are not unique
# warning: genes in ceramide biosynthetic process are not unique
# warning: genes in microtubule polymerization are not unique
# warning: genes in protein export from nucleus are not unique
# warning: genes in protein localization to kinetochore are not unique
# warning: genes in tRNA pseudouridine synthesis are not unique
# warning: genes in nucleobase transport are not unique
# warning: genes in protein exit from endoplasmic reticulum are not unique
# warning: genes in protein O-linked mannosylation are not unique
# warning: genes in glycerol metabolic process are not unique
# warning: genes in barrier septum assembly are not unique
# warning: genes in regulation of RNA polymerase II transcriptional preinitiation complex assembly are not unique
# warning: genes in sterol biosynthetic process are not unique
# warning: genes in Arp2/3 complex-mediated actin nucleation are not unique
# warning: genes in regulation of gene expression are not unique
# warning: genes in maintenance of translational fidelity are not unique
# warning: genes in regulation of transcription from RNA polymerase II promoter in response to osmotic stress are not unique
# warning: genes in maintenance of chromatin silencing at telomere are not unique
# warning: genes in protein localization to nuclear inner membrane are not unique
# warning: genes in nucleocytoplasmic transport are not unique
# warning: genes in nuclear pore organization are not unique
# warning: genes in regulation of DNA replication are not unique
# warning: genes in intralumenal vesicle formation are not unique
# warning: genes in stress granule assembly are not unique
# warning: genes in termination of RNA polymerase II transcription, exosome-dependent are not unique
# warning: genes in replication fork processing are not unique
# warning: genes in formin-nucleated actin cable assembly are not unique
# warning: genes in regulation of cell growth are not unique
# warning: genes in negative regulation of DNA-dependent DNA replication are not unique
# warning: genes in iron ion transport are not unique
# warning: genes in histone H3-K4 methylation are not unique
# warning: genes in DNA geometric change are not unique
# warning: genes in activation of GTPase activity are not unique
# warning: genes in protein localization to vacuole are not unique
# warning: genes in riboflavin biosynthetic process are not unique
# warning: genes in serine family amino acid biosynthetic process are not unique
# warning: genes in galactose catabolic process are not unique
# warning: genes in glucose 6-phosphate metabolic process are not unique
# warning: genes in positive regulation of autophagy are not unique
# warning: genes in nuclear-transcribed mRNA catabolic process, exonucleolytic are not unique
# warning: genes in protein localization to chromatin are not unique
# warning: genes in negative regulation of transcription involved in G1/S transition of mitotic cell cycle are not unique
# warning: genes in positive regulation of TORC1 signaling are not unique
# warning: genes in cortical actin cytoskeleton organization are not unique
# warning: genes in kinetochore assembly are not unique
# warning: genes in protein localization to endosome are not unique
# warning: genes in regulation of intracellular transport are not unique
# warning: genes in ubiquitin-dependent endocytosis are not unique
# warning: genes in maturation of 5.8S rRNA are not unique
# warning: genes in triglyceride catabolic process are not unique
# warning: genes in regulation of Rho protein signal transduction are not unique
# warning: genes in regulation of meiotic DNA double-strand break formation are not unique
# warning: genes in trehalose metabolism in response to stress are not unique
# warning: genes in tRNA gene clustering are not unique
# warning: genes in nuclear pore complex assembly are not unique
# warning: genes in phosphatidylserine metabolic process are not unique
# warning: genes in very long-chain fatty acid metabolic process are not unique
# warning: genes in translation reinitiation are not unique
# warning: genes in endoplasmic reticulum membrane organization are not unique
# warning: genes in calcium ion transmembrane transport are not unique
# warning: genes in C-terminal protein lipidation are not unique
# warning: genes in peptidyl-lysine methylation are not unique
# warning: genes in regulation of histone H2B conserved C-terminal lysine ubiquitination are not unique
# warning: genes in DNA double-strand break attachment to nuclear envelope are not unique
# warning: genes in protein oligomerization are not unique
# warning: genes in RNA metabolic process are not unique
# warning: genes in mitotic spindle organization are not unique
# warning: genes in replication-born double-strand break repair via sister chromatid exchange are not unique
# warning: genes in aromatic amino acid family metabolic process are not unique
# warning: genes in protein modification by small protein conjugation are not unique
# warning: genes in mRNA metabolic process are not unique
# warning: genes in protein transport are not unique
# warning: genes in snRNA 3'-end processing are not unique
# warning: genes in protein palmitoylation are not unique
# warning: genes in regulation of cytoplasmic mRNA processing body assembly are not unique
# warning: genes in cellular response to misfolded protein are not unique
# warning: genes in regulation of phosphate metabolic process are not unique
# warning: genes in cellular response to UV are not unique
# warning: genes in positive regulation of receptor-mediated endocytosis are not unique
# warning: genes in regulation of transcription from RNA polymerase II promoter by glucose are not unique
# warning: genes in sphingolipid catabolic process are not unique
# warning: genes in regulation of glycogen biosynthetic process are not unique
# warning: genes in ribonucleoprotein complex assembly are not unique
# warning: genes in regulation of pheromone-dependent signal transduction involved in conjugation with cellular fusion are not unique
# warning: genes in folic acid-containing compound biosynthetic process are not unique
# warning: genes in ceramide metabolic process are not unique
# 'gene'
# cellular protein modification process
# ```json
# [
#     {
#         "gene": "UBC9"
#     },
#     {
#         "gene": "SMT3"
#     },
#     {
#         "gene": "E1"
#     },
#     {
#         "gene": "UBA1"
#     },
#     {
#         "gene": "E2"
#     },
#     {
#         "gene": "UFD2"
#     },
#     {
#         "gene": "UFD4"
#     },
#     {
#         "gene": "UBC4"
#     },
#     {
#         "gene": "UBC5"
#     },
#     {
#         "gene": "UBI4"
#     },
#     {
#         "gene": "GLN1"
#     },
#     {
#         "enzyme": "Ub-activating enzymes"
#     },
#     {
#         "enzyme": "Ub-conjugating enzyme"
#     }
# ]
# ```
# warning: genes in positive regulation of DNA-dependent DNA replication initiation are not unique
# warning: genes in nuclear polyadenylation-dependent snoRNA catabolic process are not unique
# warning: genes in nuclear polyadenylation-dependent snRNA catabolic process are not unique
# warning: genes in fatty acid oxidation are not unique
# warning: genes in pyridoxine biosynthetic process are not unique
# warning: genes in cation transport are not unique
# warning: genes in internal peptidyl-lysine acetylation are not unique
# warning: genes in telomere organization are not unique
# warning: genes in regulation of phospholipid translocation are not unique
# warning: genes in negative regulation of invasive growth in response to glucose limitation are not unique
# warning: genes in hexose catabolic process are not unique
# warning: genes in rRNA metabolic process are not unique
# warning: genes in multivesicular body sorting pathway are not unique
# warning: genes in sulfur amino acid biosynthetic process are not unique
# warning: genes in mitochondrion localization are not unique
# warning: genes in spliceosomal snRNP assembly are not unique
# warning: genes in regulation of protein catabolic process are not unique
# warning: genes in pyrimidine nucleobase metabolic process are not unique
# warning: genes in mitotic actomyosin contractile ring assembly are not unique
# warning: genes in lipid biosynthetic process are not unique
# warning: genes in steroid metabolic process are not unique
# warning: genes in carboxylic acid transport are not unique
# warning: genes in spindle assembly are not unique
# warning: genes in mitotic G2/M transition checkpoint are not unique
# warning: genes in RNA processing are not unique
# warning: genes in protein-DNA complex assembly are not unique
# warning: genes in regulation of ribosomal protein gene transcription from RNA polymerase II promoter are not unique
# warning: genes in aromatic amino acid family catabolic process are not unique
# warning: genes in cellular monovalent inorganic cation homeostasis are not unique
# warning: genes in cotranslational protein targeting to membrane are not unique
# warning: genes in regulation of signal transduction are not unique
# warning: genes in activation of protein kinase activity are not unique
# warning: genes in negative regulation of MAP kinase activity are not unique
# warning: genes in RNA methylation are not unique
# warning: genes in sulfur compound catabolic process are not unique
# warning: genes in positive regulation of actin filament bundle assembly are not unique
# warning: genes in mRNA cis splicing, via spliceosome are not unique
# warning: genes in regulation of meiosis I are not unique
# warning: genes in meiosis II are not unique
# warning: genes in protein deneddylation are not unique
# warning: genes in positive regulation of mitotic cell cycle phase transition are not unique
# warning: genes in positive regulation of dephosphorylation are not unique
# warning: genes in positive regulation of protein serine/threonine kinase activity are not unique
# warning: genes in positive regulation of protein complex assembly are not unique
# warning: genes in chaperone mediated protein folding requiring cofactor are not unique
# warning: genes in regulation of mitotic cell cycle phase transition are not unique
# warning: genes in sister chromatid segregation are not unique
# warning: genes in peptide metabolic process are not unique
# warning: genes in RNA 3'-end processing are not unique
# warning: genes in regulation of histone deacetylation are not unique
# warning: genes in organelle transport along microtubule are not unique
# warning: genes in regulation of protein export from nucleus are not unique
# warning: genes in positive regulation of actin filament polymerization are not unique
# warning: genes in regulation of actin filament polymerization are not unique
# warning: genes in positive regulation of actin nucleation are not unique
# warning: genes in regulation of MAPK cascade are not unique
# warning: genes in L-serine metabolic process are not unique
# warning: genes in cellular glucose homeostasis are not unique
# warning: genes in regulation of G2/M transition of mitotic cell cycle are not unique
# warning: genes in UDP-N-acetylglucosamine metabolic process are not unique
# warning: genes in tRNA aminoacylation are not unique
# warning: genes in positive regulation of cell growth are not unique
# warning: genes in regulation of dephosphorylation are not unique
# warning: genes in coenzyme biosynthetic process are not unique
# warning: genes in acetyl-CoA metabolic process are not unique
# warning: genes in nuclear import are not unique
# warning: genes in 7-methylguanosine RNA capping are not unique
# warning: genes in DNA metabolic process are not unique
# warning: genes in quinone biosynthetic process are not unique
# warning: genes in mRNA-containing ribonucleoprotein complex export from nucleus are not unique
# warning: genes in actin filament bundle organization are not unique
# warning: genes in cellular protein complex assembly are not unique
# warning: genes in mitochondrial transmembrane transport are not unique
# warning: genes in histone modification are not unique
# warning: genes in monocarboxylic acid metabolic process are not unique
# warning: genes in alcohol biosynthetic process are not unique
# warning: genes in primary alcohol metabolic process are not unique
# warning: genes in carbohydrate catabolic process are not unique
# warning: genes in zinc ion homeostasis are not unique
# warning: genes in organic cyclic compound biosynthetic process are not unique
# warning: genes in peptidyl-serine modification are not unique
# warning: genes in peptidyl-threonine modification are not unique
# warning: genes in regulation of meiotic cell cycle are not unique
# warning: genes in regulation of cellular amino acid metabolic process are not unique
# warning: genes in glutamate metabolic process are not unique
# warning: genes in mitotic nuclear division are not unique
# warning: genes in protein targeting are not unique
# warning: genes in positive regulation of cell communication are not unique
# warning: genes in RNA splicing, via transesterification reactions with guanosine as nucleophile are not unique
# warning: genes in DNA biosynthetic process are not unique
# warning: genes in IMP biosynthetic process are not unique
# warning: genes in tRNA transcription are not unique
# warning: genes in glyoxylate metabolic process are not unique
# warning: genes in DNA strand elongation are not unique
# warning: genes in monovalent inorganic cation homeostasis are not unique
# warning: genes in rRNA-containing ribonucleoprotein complex export from nucleus are not unique
# warning: genes in rRNA transport are not unique
# warning: genes in RNA biosynthetic process are not unique
# warning: genes in ERAD pathway are not unique
# warning: genes in cysteine metabolic process are not unique
# warning: genes in cellular amino acid biosynthetic process are not unique
# warning: genes in branched-chain amino acid metabolic process are not unique
# warning: genes in erythrose 4-phosphate/phosphoenolpyruvate family amino acid catabolic process are not unique
# warning: genes in L-phenylalanine metabolic process are not unique
# warning: genes in ribonucleoprotein complex disassembly are not unique
# warning: genes in progressive alteration of chromatin involved in replicative cell aging are not unique
# warning: genes in heterochromatin organization are not unique
# warning: genes in transition metal ion transport are not unique
# warning: genes in cyclic-nucleotide-mediated signaling are not unique
# warning: genes in DNA repair complex assembly are not unique
# warning: genes in non-recombinational repair are not unique
# warning: genes in cytokinesis, site selection are not unique
# warning: genes in cellular response to nitrogen levels are not unique
# warning: genes in nucleobase biosynthetic process are not unique
# warning: genes in positive regulation of gene expression, epigenetic are not unique
# warning: genes in carbon catabolite repression of transcription from RNA polymerase II promoter are not unique
# warning: genes in phytosteroid biosynthetic process are not unique
# warning: genes in cellular alcohol biosynthetic process are not unique
# warning: genes in establishment of protein localization to endoplasmic reticulum are not unique
# warning: genes in mitotic cell cycle phase transition are not unique
# warning: genes in cell cycle G2/M phase transition are not unique
# warning: genes in alpha-amino acid metabolic process are not unique
# warning: genes in monocarboxylic acid biosynthetic process are not unique
# warning: genes in cellular macromolecule catabolic process are not unique
# warning: genes in posttranscriptional regulation of gene expression are not unique
# warning: genes in regulation of cellular protein metabolic process are not unique
# warning: genes in assembly of actomyosin apparatus involved in cytokinesis are not unique
# warning: genes in regulation of DNA-dependent DNA replication are not unique
# warning: genes in RNA splicing, via endonucleolytic cleavage and ligation are not unique
# warning: genes in RNA splicing, via transesterification reactions with bulged adenosine as nucleophile are not unique
# warning: genes in rRNA 3'-end processing are not unique
# warning: genes in protein modification by small protein removal are not unique
# warning: genes in organelle assembly are not unique
# warning: genes in regulation of ER to Golgi vesicle-mediated transport by GTP hydrolysis are not unique
# warning: genes in regulation of organelle organization are not unique
# warning: genes in negative regulation of protein polymerization are not unique
# warning: genes in regulation of mating projection assembly are not unique
# warning: genes in RNA transport are not unique
# warning: genes in regulation of lipid biosynthetic process are not unique
# warning: genes in cellular response to acid chemical are not unique
# warning: genes in positive regulation of organelle assembly are not unique
# warning: genes in regulation of protein serine/threonine kinase activity are not unique
# warning: genes in regulation of transcription from RNA polymerase II promoter by pheromones are not unique
# warning: genes in glycolipid biosynthetic process are not unique
# warning: genes in regulation of mRNA splicing, via spliceosome are not unique
# warning: genes in chitin metabolic process are not unique
# warning: genes in regulation of small GTPase mediated signal transduction are not unique
# warning: genes in fungal-type cell wall polysaccharide biosynthetic process are not unique
# warning: genes in protein deacetylation are not unique
# warning: genes in glyceraldehyde-3-phosphate metabolic process are not unique
# warning: genes in beta-glucan biosynthetic process are not unique
# warning: genes in regulation of growth of unicellular organism as a thread of attached cells are not unique
# the JSON object must be str, bytes or bytearray, not NoneType
# negative regulation of transposition
# ```json
# [
#     {"gene": "ATF1"},
#     {"gene": "NFI1"},
#     {"gene": "PDR5"},
#     {"gene": "SPT3"},
#     {"gene": "YKU70"},
#     {"gene": "YKU80"},
#     {"gene": "YML128C"},
#     {"gene": "YMR116C"},
#     {"gene": "YNR036C"},
#     {"gene": "YNR039C"},
#     {"gene": "YNR045W"},
#     {"gene": "YNR047W"},
#     {"gene": "YNR050C"},
#     {"gene": "YPA1"},
#     {"gene": "YRF1-1"},
#     {"gene": "YRF1-10"},
#     {"gene": "YRF1-12"},
#     {"gene": "YRF1-13"},
#     {"gene": "YRF1-14"},
#     {"gene": "YRF1-15"},
#     {"gene": "YRF1-16"},
#     {"gene": "YRF1-17"},
#     {"gene": "YRF1-18"},
#     {"gene": "YRF1-19"},
#     {"gene": "YRF1-2"},
#     {"gene": "YRF1-20"},
#     {"gene": "YRF1-21"},
#     {"gene": "YRF1-22"},
#     {"gene": "YRF1-23"},
#     {"gene": "YRF1-24"},
#     {"gene": "YRF1-25"},
#     {"gene": "YRF1-26"},
#     {"gene": "YRF1-27"},
#     {"gene": "YRF1-28B"},
#     {"gene": "YRF1-28C"},
#     {"gene": "YRF1-29"},
#     {"gene": "YRF1-3"},
#     {"gene": "YRF1-30"},
#     {"gene": "YRF1-31"},
#     {"gene": "YRF1-32"},
#     {"gene": "YRF1-33"},
#     {"gene": "YRF1-34"},
#     {"gene": "YRF1-35"},
#     {"gene": "YRF1-36"},
#     {"gene": "YRF1-37"},
#     {"gene": "YRF1-38"},
#     {"gene": "YRF1-39"},
#     {"gene": "YRF1-4"},
#     {"gene": "YRF1-40"},
#     {"gene": "YRF1-41"},
#     {"gene": "YRF1-42"},
#     {"gene": "YRF1-43"},
#     {"gene": "YRF1-44"},
#     {"gene": "YRF1-45"},
#     {"gene": "YRF1-46"},
#     {"gene": "YRF1-47"},
#     {"gene": "YRF1-48"},
#     {"gene": "YRF1-49"},
#     {"gene": "YRF1-5"},
#     {"gene": "YRF1-50"},
#     {"gene": "YRF1-51"},
#     {"gene": "YRF1-52"},
#     {"gene": "YRF1-53"},
#     {"gene": "YRF1-54"},
#     {"gene": "YRF1-6"},
#     {"gene": "YRF1-61"},
#     {"gene": "YRF1-62"},
#     {"gene": "YRF1-63"},
#     {"gene": "YRF1-64"},
#     {"gene": "YRF1-65"},
#     {"gene": "YRF1-66"},
#     {"gene": "YRF1-67"},
#     {"gene": "YRF1-68"},
#     {"gene": "YRF1-69"},
#     {"gene": "YRF1-7"},
#     {"gene": "YRF1-70"},
#     {"gene": "YRF1-71"},
#     {"gene": "YRF1-72"},
#     {"gene": "YRF1-73"},
#     {"gene": "YRF1-74"},
#     {"gene": "YRF1-75"},
#     {"gene": "YRF1-76"},
#     {"gene": "YRF1-77"},
#     {"gene": "YRF1-78"},
#     {"gene": "YRF1-79"},
#     {"gene": "YRF1-8"},
#     {"gene": "YRF1-80"},
#     {"gene": "YRF1-81"},
#     {"gene": "YRF1-82"},
#     {"gene": "YRF1-83"},
#     {"gene": "YRF1-84"},
#     {"gene": "YRF1-85"},
#     {"gene": "YRF1-86"},
#     {"gene": "YRF1-87"},
#     {"gene": "YRF1-88"},
#     {"gene": "YRF1-89"},
#     {"gene": "YRF1-9"},
#     {"gene": "YRF1-90"},
#     {"gene": "YRF1-91"},
#     {"gene": "YRF1-92"},
#     {"gene": "YRF1-93"},
#     {"gene": "YRF1-94"},
#     {"gene": "YRF1-95"},
#     {"gene": "YRF1-96"},
#     {"gene": "YRF1-97"},
#     {"gene": "YRF1-98"},
#     {"gene": "YRF1-99"},
#     {"gene": "YRF2-1"},
#     {"gene": "YRF2-10"},
#     {"gene": "YRF2-11"},
#     {"gene": "YRF2-12"},
#     {"gene": "YRF2-13"},
#     {"gene": "YRF2-14"},
#     {"gene": "YRF2-15"},
#     {"gene": "YRF2-16"},
#     {"gene": "YRF2-17"},
#     {"gene": "YRF2-18"},
#     {"gene": "YRF2-19"},
#     {"gene": "YRF2-2"},
#     {"gene": "YRF2-20"},
#     {"gene": "YRF2-21"},
#     {"gene": "YRF2-22"},
#     {"gene": "YRF2-23"},
#     {"gene": "YRF2-24"},
#     {"gene": "YRF2-25"},
#     {"gene": "YRF2-26"},
#     {"gene": "YRF2-27"},
#     {"gene": "YRF2-28"},
#     {"gene": "YRF2-29"},
#     {"gene": "YRF2-3"},
#     {"gene": "YRF2-30"},
#     {"gene": "YRF2-31"},
#     {"gene": "YRF2-32"},
#     {"gene": "YRF2-33"},
#     {"gene": "YRF2-34"},
#     {"gene": "YRF2-35"},
#     {"gene": "YRF2-36"},
#     {"gene": "YRF2-37"},
#     {"gene": "YRF2-38"},
#     {"gene": "YRF2-39"},
#     {"gene": "YRF2-4"},
#     {"gene": "YRF2-40"},
#     {"gene": "YRF2-41"},
#     {"gene": "YRF2-42"},
#     {"gene": "YRF2-43"},
#     {"gene": "YRF2-44"},
#     {"gene": "YRF2-45"},
#     {"gene": "YRF2-46"},
#     {"gene": "YRF2-47"},
#     {"gene": "YRF2-48"},
#     {"gene": "YRF2-49"},
#     {"gene": "YRF2-5"},
#     {"gene": "YRF2-50"},
#     {"gene": "YRF2-51"},
#     {"gene": "YRF2-52"},
#     {"gene": "YRF2-53"},
#     {"gene": "YRF2-54"},
#     {"gene": "YRF2-55"},
#     {"gene": "YRF2-56"},
#     {"gene": "YRF2-57"},
#     {"gene": "YRF2-58"},
#     {"gene": "YRF2-59"},
#     {"gene": "YRF2-6"},
#     {"gene": "YRF2-60"},
#     {"gene": "YRF2-61"},
#     {"gene": "YRF2-62"},
#     {"gene": "YRF2-63"},
#     {"gene": "YRF2-64"},
#     {"gene": "YRF2-65"},
#     {"gene": "YRF2-66"},
#     {"gene": "YRF2-67"},
#     {"gene": "YRF2-68"},
#     {"gene": "YRF2-69"},
#     {"gene": "YRF2-7"},
#     {"gene": "YRF2-70"},
#     {"gene": "YRF2-71"},
#     {"gene": "YRF2-72"},
#     {"gene": "YRF2-73"},
#     {"gene": "YRF2-74"},
#     {"gene": "YRF2-75"},
#     {"gene": "YRF2-76"},
#     {"gene": "YRF2-77"},
#     {"gene": "YRF2-78"},
#     {"gene": "YRF2-79"},
#     {"gene": "YRF2-8"},
#     {"gene": "YRF2-80"},
#     {"gene": "YRF2-81"},
#     {"gene": "YRF2-82"},
#     {"gene": "YRF2-83"},
#     {"gene": "YRF2-84"},
#     {"gene": "YRF2-85"},
#     {"gene": "YRF2-86"},
#     {"gene": "YRF2-87"},
#     {"gene": "YRF2-88"},
#     {"gene": "YRF2-89"},
#     {"gene": "YRF2-9"},
#     {"gene": "YRF2-90"},
#     {"gene": "YRF2-91"},
#     {"gene": "YRF2-92"},
#     {"gene": "YRF2-93"},
#     {"gene": "YRF2-94"},
#     {"gene": "YRF2-95"},
#     {"gene": "YRF2-96"},
#     {"gene": "YRF2-97"},
#     {"gene": "YRF2-98"},
#     {"gene": "YRF2-99"},
#     {"gene": "YRF3-1"},
#     {"gene": "YRF3-10"},
#     {"gene": "YRF3-11"},
#     {"gene": "YRF3-12"},
#     {"gene": "YRF3-13"},
#     {"gene": "YRF3-14"},
#     {"gene": "YRF3-15"},
#     {"gene": "YRF3-16"},
#     {"gene": "YRF3-17"},
#     {"gene": "YRF3-18"},
#     {"gene": "YRF3-19"},
#     {"gene": "YRF3-2"},
#     {"gene": "YRF3-20"},
#     {"gene": "YRF3-21"},
#     {"gene": "YRF3-22"},
#     {"gene": "YRF3-23"},
#     {"gene": "YRF3-24"},
#     {"gene": "YRF3-25"},
#     {"gene": "YRF3-26"},
#     {"gene": "YRF3-27"},
#     {"gene": "YRF3-28"},
#     {"gene": "YRF3-29"},
#     {"gene": "YRF3-3"},
#     {"gene": "YRF3-30"},
#     {"gene": "YRF3-31"},
#     {"gene": "YRF3-32"},
#     {"gene": "YRF3-33"},
#     {"gene": "YRF3-34"},
#     {"gene": "YRF3-35"},
#     {"gene": "YRF3-36"},
#     {"gene": "YRF3-37"},
#     {"gene": "YRF3-38"},
#     {"gene": "YRF3-39"},
#     {"gene": "YRF3-4"},
#     {"gene": "YRF3-40"},
#     {"gene": "YRF3-41"},
#     {"gene": "YRF3-42"},
#     {"gene": "YRF3-43"},
#     {"gene": "YRF3-44"},
#     {"gene": "YRF3-45"},
#     {"gene": "YRF3-46"},
#     {"gene": "YRF3-47"},
#     {"gene": "YRF3-48"},
#     {"gene": "YRF3-49"},
#     {"gene": "YRF3-5"},
#     {"gene": "YRF3-50"},
#     {"gene": "YRF3-51"},
#     {"gene": "YRF3-52"},
#     {"gene": "YRF3-53"},
#     {"gene": "YRF3-54"},
#     {"gene": "YRF3-55"},
#     {"gene": "YRF3-56"},
#     {"gene": "YRF3-57"},
#     {"gene": "YRF3-58"},
#     {"gene": "YRF3-59"},
#     {"gene": "YRF3-6"},
#     {"gene": "YRF3-60"},
#     {"gene": "YRF3-61"},
#     {"gene": "YRF3-62"},
#     {"gene": "YRF3-63"},
#     {"gene": "YRF3-64"},
#     {"gene": "YRF3-65"},
#     {"gene": "YRF3-66"},
#     {"gene": "YRF3-67"},
#     {"gene": "YRF3-68"},
#     {"gene": "YRF3-69"},
#     {"gene": "YRF3-7"},
#     {"gene": "YRF3-70"},
#     {"gene": "YRF3-71"},
#     {"gene": "YRF3-72"},
#     {"gene": "YRF3-73"},
#     {"gene": "YRF3-74"},
#     {"gene": "YRF3-75"},
#     {"gene": "YRF3-76"},
#     {"gene": "YRF3-77"},
#     {"gene": "YRF3-78"},
#     {"gene": "YRF3-79"},
#     {"gene": "YRF3-8"},
#     {"gene": "YRF3-80"},
#     {"gene": "YRF3-81"},
#     {"gene": "YRF3-82"},
#     {"gene": "YRF3-83"},
#     {"gene": "YRF3-84"},
#     {"gene": "YRF3-85"},
#     {"gene": "YRF3-86"},
#     {"gene": "YRF3-87"},
#     {"gene": "YRF3-88"},
#     {"gene": "YRF3-89"},
#     {"gene": "YRF3-9"},
#     {"gene": "YRF3-90"},
#     {"gene": "YRF3-91"},
#     {"gene": "YRF3-92"},
#     {"gene": "YRF3-93"},
#     {"gene": "YRF3-94"},
#     {"gene": "YRF3-95"},
#     {"gene": "YRF3-96"},
#     {"gene": "YRF3-97"},
#     {"gene": "YRF3-98"},
#     {"gene": "YRF3-99"},
#     {"gene": "YRF5-1"},
#     {"gene": "YRF5-10"},
#     {"gene": "YRF5-11"},
#     {"gene": "YRF5-12"},
#     {"gene": "YRF5-13"},
#     {"gene": "YRF5-14"},
#     {"gene": "YRF5-15"},
#     {"gene": "YRF5-16"},
#     {"gene": "YRF5-17"},
#     {"gene": "YRF5-18"},
#     {"gene": "YRF5-19"},
#     {"gene": "YRF5-2"},
#     {"gene": "YRF5-20"},
#     {"gene": "YRF5-21"},
#     {"gene": "YRF5-22"},
#     {"gene": "YRF5-23"},
#     {"gene": "YRF5-24"},
#     {"gene": "YRF5-25"},
#     {"gene": "YRF5-26"},
#     {"gene": "YRF5-27"},
#     {"gene": "YRF5-28"},
#     {"gene": "YRF5-29"},
#     {"gene": "YRF5-3"},
#     {"gene": "YRF5-30"},
#     {"gene": "YRF5-31"},
#     {"gene": "YRF5-32"},
#     {"gene": "YRF5-33"},
#     {"gene": "YRF5-34"},
#     {"gene": "YRF5-35"},
#     {"gene": "YRF5-36"},
#     {"gene": "YRF5-37"},
#     {"gene": "YRF5-38"},
#     {"gene": "YRF5-39"},
#     {"gene": "YRF5-4"},
#     {"gene": "YRF5-40"},
#     {"gene": "YRF5-41"},
#     {"gene": "YRF5-42"},
#     {"gene": "YRF5-43"},
#     {"gene": "YRF5-44"},
#     {"gene": "YRF5-45"},
#     {"gene": "YRF5-46"},
#     {"gene": "YRF5-47"},
#     {"gene": "YRF5-48"},
#     {"gene": "YRF5-49"},
#     {"gene": "YRF5-5"},
#     {"gene": "YRF5-50"},
#     {"gene": "YRF5-51"},
#     {"gene": "YRF5-52"},
#     {"gene": "YRF5-53"},
#     {"gene": "YRF5-54"},
#     {"gene": "YRF5-55"},
#     {"gene": "YRF5-56"},
#     {"gene": "YRF5-57"},
#     {"gene": "YRF5-58"},
#     {"gene": "YRF5-59"},
#     {"gene": "YRF5-6"},
#     {"gene": "YRF5-60"},
#     {"gene": "YRF5-61"},
#     {"gene": "YRF5-62"},
#     {"gene": "YRF5-63"},
#     {"gene": "YRF5-64"},
#     {"gene": "YRF5-65"},
#     {"gene": "YRF5-66"},
#     {"gene": "YRF5-67"},
#     {"gene": "YRF5-68"},
#     {"gene": "YRF5-69"},
#     {"gene": "YRF5-7"},
#     {"gene": "YRF5-70"},
#     {"gene": "Y
# warning: genes in regulation of actin filament-based process are not unique
# warning: genes in regulation of transcription elongation from RNA polymerase I promoter are not unique
# warning: genes in proton-transporting ATP synthase complex assembly are not unique
# warning: genes in cellular response to reactive oxygen species are not unique
# warning: genes in metal ion homeostasis are not unique
# warning: genes in regulation of nuclear division are not unique
# warning: genes in regulation of cell cycle process are not unique
# warning: genes in chromatin organization involved in negative regulation of transcription are not unique
# warning: genes in regulation of cell division are not unique
# warning: genes in regulation of protein dephosphorylation are not unique
# warning: genes in oligosaccharide metabolic process are not unique
# warning: genes in metallo-sulfur cluster assembly are not unique
# warning: genes in dicarboxylic acid catabolic process are not unique
# warning: genes in spindle assembly checkpoint are not unique
# warning: genes in positive regulation of chromosome segregation are not unique
# warning: genes in mannoprotein biosynthetic process are not unique
# warning: genes in ncRNA metabolic process are not unique
# warning: genes in macromolecule catabolic process are not unique
# warning: genes in chromatin disassembly are not unique
# warning: genes in cation homeostasis are not unique
# warning: genes in mitochondrial tRNA modification are not unique
# warning: genes in nuclear RNA surveillance are not unique
# warning: genes in rRNA 5'-end processing are not unique
# warning: genes in endoplasmic reticulum to cytosol transport are not unique
# warning: genes in positive regulation of catabolic process are not unique
# warning: genes in positive regulation of metaphase/anaphase transition of cell cycle are not unique
# warning: genes in regulation of ubiquitin protein ligase activity are not unique
# warning: genes in regulation of nucleotide-excision repair are not unique
# warning: genes in microtubule polymerization or depolymerization are not unique
# warning: genes in snRNA modification are not unique
# warning: genes in protein polymerization are not unique
# warning: genes in nuclear export are not unique
# warning: genes in mRNA modification are not unique
# warning: genes in organelle fusion are not unique
# warning: genes in cell septum assembly are not unique
# warning: genes in regulation of mRNA metabolic process are not unique
# ...
#     {"gene": "RPL148"},
#     {"gene": "RPL149"},
#     {"gene": "RPL150"},
#     {"gene": "RPL151"},
#     {"gene": "RPL152"},
#     {"gene": "RPL153"},
#     {"gene": "RPL154"},
#     {"gene": "RPL155"},
#     {"gene": "RPL156"},
#     {"gene": "RPL157"},
#     {"gene": "RPL158"},
#     {"gene": "RPL159"},
#     {"gene": "RPL160"},
#     {"gene": "RPL161"},
#     {"gene": "RPL162"},
#     {"gene": "RPL163"},
#     {"gene": "RPL164"},
#     {"gene": "RPL165"},
#     {"gene": "RPL166"},
#     {"gene": "RPL167"},
#     {"gene": "RPL168"},
#     {"gene": "RPL169"},
#     {"gene": "RPL170"},
#     {"gene": "RPL171"},
#     {"gene": "RPL172"},
#     {"gene": "RPL173"},
#     {"gene": "RPL174"},
#     {"gene": "RPL175"},
#     {"gene": "RPL176"},
#     {"gene": "RPL177"},
#     {"gene": "RPL178"},
#     {"gene": "RPL179"},
#     {"gene": "RPL180"},
#     {"gene": "RPL181"},
#     {"gene": "RPL182"},
#     {"gene": "RPL183"},
#     {"gene": "RPL184"},
#     {"gene": "RPL185"},
#     {"gene": "RPL186"},
#     {"gene": "RPL187"},
#     {"gene": "RPL188"},
#     {"gene": "RPL189"},
#     {"gene": "RPL190"},
#     {"gene": "RPL191"},
#     {"gene": "RPL192"},
#     {"gene": "RPL193"},
#     {"gene": "RPL194"},
#     {"gene": "RPL195"},
#     {"gene": "RPL196"},
#     {"gene": "RPL197"},
#     {"gene": "RPL198"},
#     {"gene": "RPL199"},
#     {"gene": "RPL200"},
#     {"gene": "RPL201"},
#     {"gene": "RPL202"},
#     {"gene": "RPL203"},
#     {"gene": "RPL204"},
#     {"gene": "RPL205"},
#     {"gene": "RPL206"},
#     {"gene": "RPL207"},
#     {"gene": "RPL208"},
#     {"gene": "RPL209"},
#     {"gene": "RPL210"},
#     {"gene": "RPL211"},
#     {"gene": "RPL212"},
#     {"gene": "RPL213"},
#     {"gene": "RPL214"},
#     {"gene": "RPL215"},
#     {"gene": "RPL216"},
#     {"gene": "RPL217"},
#     {"gene": "RPL218"},
#     {"gene": "RPL219"},
#     {"gene": "RPL220"},
#     {"gene": "RPL221"},
#     {"gene": "RPL222"},
#     {"gene": "RPL223"},
#     {"gene": "RPL224"},
#     {"gene": "RPL225"},
#     {"gene": "RPL226"},
#     {"gene": "RPL227"},
#     {"gene": "RPL228"},
#     {"gene": "RPL229"},
#     {"gene": "RPL230"},
#     {"gene": "RPL231"},
#     {"gene": "RPL232"},
#     {"gene": "RPL233"},
#     {"gene": "RPL234"},
#     {"gene": "RPL235"},
#     {"gene": "RPL236"},
#     {"gene": "RPL237"},
#     {"gene": "RPL238"},
#     {"gene": "RPL239"},
#     {"gene": "RPL240"},
#     {"gene": "RPL241"},
#     {"gene": "RPL242"},
#     {"gene": "RPL243"},
#     {"gene": "RPL244"},
#     {"gene": "RPL245"},
#     {"gene": "RPL246"},
#     {"gene": "RPL247"},
#     {"gene": "RPL248"},
#     {"gene": "RPL249"},
#     {"gene": "RPL250"},
#     {"gene": "RPS0A"},
#     {"gene": "RPS0B"},
#     {"gene": "RPS1A"},
#     {"gene": "RPS1B"},
#     {"gene": "RPS2"},
#     {"gene": "RPS3"},
#     {"gene": "RPS4A"},
#     {"gene": "RPS4B"},
#     {"gene": "RPS5"},
#     {"gene": "RPS6A"},
#     {"gene": "RPS6B"},
#     {"gene": "RPS7A"},
#     {"gene": "RPS7B"},
#     {"gene": "RPS8A"},
#     {"gene": "RPS8B"},
#     {"gene": "RPS9A"},
#     {"gene": "RPS9B"},
#     {"gene": "RPS10A"},
#     {"gene": "RPS10B"},
#     {"gene": "RPS11A"},
#     {"gene": "RPS11B"},
#     {"gene": "RPS12"},
#     {"gene": "RPS13"},
#     {"gene": "RPS14A"},
#     {"gene": "RPS14B"},
#     {"gene": "RPS15A"},
#     {"gene": "RPS15B"},
#     {"gene": "RPS16A"},
#     {"gene": "RPS16B"},
#     {"gene": "RPS17A"},
#     {"gene": "RPS17B"},
#     {"gene": "RPS18A"},
#     {"gene": "RPS18B"},
#     {"gene": "RPS19A"},
#     {"gene": "RPS19B"},
#     {"gene": "RPS20"},
#     {"gene": "RPS21A"},
#     {"gene": "RPS21B"},
#     {"gene": "RPS22A"},
#     {"gene": "RPS22B"},
#     {"gene": "RPS23A"},
#     {"gene": "RPS23B"},
#     {"gene": "RPS24A"},
#     {"gene": "RPS24B"},
#     {"gene": "RPS25A"},
#     {"gene": "RPS25B"},
#     {"gene": "RPS26A"},
#     {"gene": "RPS26B"},
#     {"gene": "RPS27A"},
#     {"gene": "RPS27B"},
#     {"gene": "RPS28A"},
#     {"gene": "RPS28B"},
#     {"gene": "RPS29A"},
#     {"gene": "RPS29B"},
#     {"gene": "RPS30A"},
#     {"gene": "RPS30B"},
#     {"gene": "RPS31"},
#     {"gene": "RPS32A"},
#     {"gene": "RPS32B"},
#     {"gene": "RPS33A"},
#     {"gene": "RPS33B"},
#     {"gene": "RPS34A"},
#     {"gene": "RPS34B"},
#     {"gene": "RPS35A"},
#     {"gene": "RPS35B"},
#     {"gene": "RPS36A"},
#     {"gene": "RPS36B"},
#     {"gene": "RPS37A"},
#     {"gene": "RPS37B"},
#     {"gene": "RPS38A"},
#     {"gene": "RPS38B"},
#     {"gene": "RPS39"},
#     {"gene": "RPS40"},
#     {"gene": "RPS41"},
#     {"gene": "RPS42"},
#     {"gene": "RPS43"},
#     {"gene": "RPS44"},
#     {"gene": "RPS45"},
#     {"gene": "RPS46"},
#     {"gene": "RPS47"},
#     {"gene": "RPS48"},
#     {"gene": "RPS49A"},
#     {"gene": "RPS49B"},
#     {"gene": "RPS50"},
#     {"gene": "RPS51"},
#     {"gene": "RPS52"},
#     {"gene": "RPS53"},
#     {"gene": "RPS54"},
#     {"gene": "RPS55"},
#     {"gene": "RPS56"},
#     {"gene": "RPS57"},
#     {"gene": "RPS58"},
#     {"gene": "RPS59"},
#     {"gene": "RPS60"},
#     {"gene": "RPS61"},
#     {"gene": "RPS62"},
#     {"gene": "RPS63"},
#     {"gene": "RPS64"},
#     {"gene": "RPS65"},
#     {"gene": "RPS66"},
#     {"gene": "RPS67"},
#     {"gene": "RPS68"},
#     {"gene": "RPS69"},
#     {"gene": "RPS70"},
#     {"gene": "RPS71"},
#     {"gene": "RPS72"},
#     {"gene": "RPS73"},
#     {"gene": "RPS74"},
#     {"gene": "RPS75"},
#     {"gene": "RPS76"},
#     {"gene": "RPS77"},
#     {"gene": "RPS78"},
#     {"gene": "RPS79"},
#     {"gene": "RPS80"},
#     {"gene": "RPS81"},
#     {"gene": "RPS82"},
#     {"gene": "RPS83"},
#     {"gene": "RPS84"},
#     {"gene": "RPS85"},
#     {"gene": "RPS86"},
#     {"gene": "RPS87"},
#     {"gene": "RPS88"},
#     {"gene": "RPS89"},
#     {"gene": "RPS90"},
#     {"gene": "RPS91"},
#     {"gene": "RPS92"},
#     {"gene": "RPS93"},
#     {"gene": "RPS94"},
#     {"gene": "RPS95"},
#     {"gene": "RPS96"},
#     {"gene": "RPS97"},
#     {"gene": "RPS98"},
#     {"gene": "RPS99"},
#     {"gene": "RPS100"},
#     {"gene": "RPS101"},
#     {"gene": "RPS102"},
#     {"gene": "RPS103"},
#     {"gene": "RPS104"},
#     {"gene": "RPS105"},
#     {"gene": "RPS106"},
#     {"gene": "RPS107"},
#     {"gene": "RPS108"},
#     {"gene": "RPS109"},
#     {"gene": "RPS110"},
#     {"gene": "RPS111"},
#     {"gene": "RPS112"},
#     {"gene": "RPS113"},
#     {"gene": "RPS114"},
#     {"gene": "RPS115"},
#     {"gene": "RPS116"},
#     {"gene": "RPS117"},
#     {"gene": "RPS118"},
#     {"gene": "RPS119"},
#     {"gene": "RPS120"},
#     {"gene": "
# warning: genes in regulation of mitotic spindle organization are not unique
# warning: genes in positive regulation of transcription from RNA polymerase II promoter in response to stress are not unique
# warning: genes in vesicle fusion with Golgi apparatus are not unique
# warning: genes in positive regulation of translational initiation are not unique
# warning: genes in regulation of mitotic cell cycle are not unique
# warning: genes in nonfunctional rRNA decay are not unique
# warning: genes in nuclear division are not unique
# warning: genes in cell morphogenesis are not unique
# warning: genes in osmosensory signaling pathway via Sho1 osmosensor are not unique
# warning: genes in regulation of transcription from RNA polymerase II promoter in response to stress are not unique
# warning: genes in protein localization to chromosome, centromeric region are not unique
# warning: genes in protein catabolic process are not unique
# warning: genes in transcriptional open complex formation at RNA polymerase II promoter are not unique
# warning: genes in mRNA polyadenylation are not unique
# warning: genes in pre-mRNA cleavage required for polyadenylation are not unique
# warning: genes in polyadenylation-dependent snoRNA 3'-end processing are not unique
# warning: genes in cellular protein complex localization are not unique
# warning: genes in mitotic spindle assembly are not unique
# warning: genes in endonucleolytic cleavage to generate mature 5'-end of SSU-rRNA from (SSU-rRNA, 5.8S rRNA, LSU-rRNA) are not unique
# warning: genes in N-glycan processing are not unique
# warning: genes in tRNA processing are not unique
# warning: genes in glycogen metabolic process are not unique
# warning: genes in protein localization to kinetochore are not unique
# warning: genes in establishment of spindle localization are not unique
# warning: genes in inositol metabolic process are not unique
# warning: genes in sterol biosynthetic process are not unique
# warning: genes in positive regulation of histone acetylation are not unique
# warning: genes in maintenance of chromatin silencing at telomere are not unique
# warning: genes in nucleocytoplasmic transport are not unique
# warning: genes in nuclear pore organization are not unique
# warning: genes in termination of RNA polymerase II transcription, poly(A)-coupled are not unique
# warning: genes in activation of GTPase activity are not unique
# warning: genes in serine family amino acid biosynthetic process are not unique
# warning: genes in nuclear-transcribed mRNA catabolic process, exonucleolytic are not unique
# warning: genes in kinetochore assembly are not unique
# warning: genes in nuclear pore distribution are not unique
# warning: genes in fatty acid metabolic process are not unique
# warning: genes in sphingolipid metabolic process are not unique
# warning: genes in positive regulation of phosphatase activity are not unique
# warning: genes in establishment of mitotic spindle localization are not unique
# warning: genes in mRNA catabolic process are not unique
# warning: genes in calcium-mediated signaling are not unique
# warning: genes in mitochondrial respiratory chain complex IV assembly are not unique
# warning: genes in phospholipid metabolic process are not unique
# warning: genes in regulation of Rho protein signal transduction are not unique
# warning: genes in DNA-templated transcription, elongation are not unique
# warning: genes in nuclear pore complex assembly are not unique
# warning: genes in actin nucleation are not unique
# warning: genes in NAD biosynthetic process are not unique
# warning: genes in RNA metabolic process are not unique
# warning: genes in protein transport are not unique
# warning: genes in lysine biosynthetic process are not unique
# warning: genes in positive regulation of protein ubiquitination are not unique
# warning: genes in calcium ion homeostasis are not unique
# warning: genes in protein insertion into ER membrane are not unique
# warning: genes in DNA replication, Okazaki fragment processing are not unique
# warning: genes in ncRNA polyadenylation are not unique
# warning: genes in nuclear polyadenylation-dependent snRNA catabolic process are not unique
# warning: genes in RNA export from nucleus are not unique
# warning: genes in positive regulation of DNA-templated transcription, elongation are not unique
# warning: genes in amino acid transmembrane transport are not unique
# warning: genes in spliceosomal snRNP assembly are not unique
# warning: genes in snoRNA transcription are not unique
# warning: genes in polyadenylation-dependent mRNA catabolic process are not unique
# warning: genes in mitochondrial protein processing are not unique
# warning: genes in spindle assembly are not unique
# warning: genes in RNA processing are not unique
# warning: genes in regulation of phospholipid biosynthetic process are not unique
# warning: genes in positive regulation of Arp2/3 complex-mediated actin nucleation are not unique
# warning: genes in terpenoid biosynthetic process are not unique
# warning: genes in protein ubiquitination involved in ubiquitin-dependent protein catabolic process are not unique
# warning: genes in cellular response to pH are not unique
# warning: genes in regulation of MAPK cascade are not unique
# warning: genes in L-serine metabolic process are not unique
# warning: genes in cellular glucose homeostasis are not unique
# warning: genes in Rab protein signal transduction are not unique
# warning: genes in regulation of RNA metabolic process are not unique
# warning: genes in protein complex assembly are not unique
# warning: genes in endonucleolytic cleavage involved in rRNA processing are not unique
# warning: genes in nuclear import are not unique
# warning: genes in purine ribonucleotide transport are not unique
# warning: genes in histone modification are not unique
# warning: genes in histidine metabolic process are not unique
# warning: genes in vesicle budding from membrane are not unique
# warning: genes in mitotic nuclear division are not unique
# warning: genes in arginine metabolic process are not unique
# warning: genes in DNA strand elongation are not unique
# warning: genes in aspartate family amino acid metabolic process are not unique
# warning: genes in branched-chain amino acid metabolic process are not unique
# warning: genes in erythrose 4-phosphate/phosphoenolpyruvate family amino acid catabolic process are not unique
# warning: genes in cyclic-nucleotide-mediated signaling are not unique
# warning: genes in regulation of cellular component organization are not unique
# warning: genes in inositol phosphate metabolic process are not unique
# warning: genes in protein-DNA complex subunit organization are not unique
# warning: genes in DNA-templated transcription, initiation are not unique
# warning: genes in phytosteroid biosynthetic process are not unique
# warning: genes in serine family amino acid metabolic process are not unique
# warning: genes in assembly of actomyosin apparatus involved in cytokinesis are not unique
# warning: genes in carbohydrate derivative biosynthetic process are not unique
# warning: genes in disaccharide metabolic process are not unique
# warning: genes in cellular macromolecule biosynthetic process are not unique
# warning: genes in negative regulation of cellular process are not unique
# warning: genes in RNA transport are not unique
# warning: genes in organonitrogen compound catabolic process are not unique
# warning: genes in cellular response to acid chemical are not unique
# warning: genes in regulation of protein serine/threonine kinase activity are not unique
# warning: genes in mitochondrial RNA metabolic process are not unique
# warning: genes in fungal-type cell wall polysaccharide biosynthetic process are not unique
# warning: genes in glycoprotein biosynthetic process are not unique
# warning: genes in negative regulation of transposition are not unique
# warning: genes in positive regulation of intracellular protein transport are not unique
# warning: genes in regulation of cytoskeleton organization are not unique
# warning: genes in positive regulation of protein modification by small protein conjugation or removal are not unique
# warning: genes in organelle inheritance are not unique
# warning: genes in negative regulation of cellular biosynthetic process are not unique
# warning: genes in tRNA wobble base modification are not unique
# warning: genes in positive regulation of chromosome segregation are not unique
# warning: genes in regulation of phosphatidylcholine biosynthetic process are not unique
# warning: genes in glycoprotein metabolic process are not unique
# warning: genes in mRNA modification are not unique
# warning: genes in monosaccharide transport are not unique
# warning: genes in nuclear transport are not unique
# warning: genes in formin-nucleated actin cable organization are not unique
# warning: genes in regulation of chromosome organization are not unique
# warning: genes in nuclear pore localization are not unique
# warning: genes in mitotic metaphase plate congression are not unique
# warning: genes in microtubule cytoskeleton organization involved in mitosis are not unique
# warning: genes in mitochondrial respiratory chain complex IV biogenesis are not unique
# warning: genes in regulation of cellular localization are not unique
# warning: genes in pore complex assembly are not unique
# warning: genes in regulation of phospholipid metabolic process are not unique
# warning: genes in nucleic acid metabolic process are not unique
# warning: genes in cargo loading into vesicle are not unique
# warning: genes in regulation of glycogen metabolic process are not unique
# warning: genes in carboxylic acid biosynthetic process are not unique
# warning: genes in regulation of helicase activity are not unique
# warning: genes in mitotic DNA replication are not unique
# failed pathways
# {'translational elongation'}
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.68s/it]
