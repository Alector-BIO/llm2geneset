# %%
import openai
from pathlib import Path
import json
import llm2geneset
import time
import pandas as pd
from rouge_score import rouge_scorer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from scipy.stats import hypergeom
from asynciolimiter import StrictLimiter
import asyncio
import tqdm.asyncio
aclient = openai.AsyncClient()
client = openai.Client()

# %%
scorer = rouge_scorer.RougeScorer(['rouge1','rouge2', 'rougeL'], use_stemmer=True)

# %%
models = ["gpt-3.5-turbo-0125", "gpt-4o-2024-05-13"]
lib_names = ["KEGG_2021_Human",
             "Reactome_2022", 
             "WikiPathway_2023_Human"]

# %%
output = []
for model in models:   
    print(model)
    for lib_name in lib_names:
        print(lib_name)
        with open("libs_human/" + model + "/" + lib_name + ".json") as f:
            gen_res = json.load(f)

        test_sets = gen_res["curated_genesets"]
        test_descr = gen_res["descr_cleaned"]
        gt_embs = llm2geneset.get_embeddings(client, test_descr)

        # use llm2geneset to generate geneset name
        res = await llm2geneset.gs_proposal(aclient, test_sets, model=model)
        most_overrepresented = [min(gene_set, key=lambda x: x[1]) for gene_set in res]
        names = [i[0] for i in most_overrepresented]
        name_embs = llm2geneset.get_embeddings(client, names)
        
        for i, ref in enumerate(test_descr):
            gt_emb = [gt_embs[i]]
            name = names[i]
            name_emb = [name_embs[i]]
            scores = scorer.score(ref, name)
            rouge1= scores['rouge1'].recall
            rouge2= scores['rouge2'].recall
            rougeL= scores['rougeL'].fmeasure      
            csim = cosine_similarity(gt_emb,name_emb).squeeze()
                
            x={"model":model,
               "library":lib_name,
               "gt_name":ref,
               "llm2geneset_name":name,
               "llm2geneset_ROUGE1":rouge1,
               "llm2geneset_ROUGE2":rouge2,   
               "llm2geneset_ROUGEL":rougeL,                  
               "llm2geneset_csim":csim}    
            output.append(x)
# Out:
# gpt-3.5-turbo-0125
# KEGG_2021_Human
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 320/320 [00:48<00:00,  6.57it/s]
# Reactome_2022
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋| 1813/1818 [01:16<00:06,  1.27s/it]
# retrying
# List about 5 biological pathways, biological processes, or cellular components that contain the following genes """SLC12A3,SLC12A4,SLC12A5,SLC12A6,SLC12A1,SLC12A2,CTNS,SLC9A3,SLC5A8,SLC9A4,SLC9A5,SLC9A7,SLC9A8,SLC9A9,CALM1,AHCYL2,SLC1A1,SLC1A2,SLC1A3,SLC1A4,SLC1A5,SLC1A6,SLC1A7,SLC5A5,SLC9A1,SLC9A2,SLC26A11,SLC12A7,SLC15A1,SLC34A3,SLC15A2,SLC38A2,SLC15A3,SLC38A1,SLC6A19,SLC6A18,SLC34A2,SLC34A1,SLC6A15,SLC6A14,SLC6A12,SLC16A10,SLC6A6,SLC26A1,SLC26A3,SLC26A2,SLC6A20,SLC15A4,SLC38A4,SLC38A3,SLC38A5,SLC4A10,SLC7A5,SLC7A6,SLC7A7,SLC7A8,SLC7A9,SLC26A9,SLC26A4,SLC26A7,SLC26A6,SLC3A1,SLC3A2,SLC7A1,SLC7A11,SLC7A10,SLC7A2,SLC7A3,SLC36A2,SLC36A1,SLC36A4,SLC17A1,SLC32A1,SLC8B1,SLC4A8,SLC4A9,SLC25A18,SLC25A10,SLC24A3,SLC24A5,SLC24A4,SLC20A2,SLC24A1,SLC43A1,SLC43A2,SLC5A12,SRI,SLC4A1,SLC20A1,SLC4A2,SLC4A3,SLC4A4,SLC4A5,SLC8A1,SLC8A2,SLC4A7,SLC8A3,SLC25A29,SLC17A6,SLC17A7,SLC17A8,SLC25A22,SLC25A26,SLC17A5""" with high confidence. Be as specific as possible. Use the following JSON schema:
# ```json
# {
#     "type": "array",
#     "items": {
#         "type": "object",
#         "properties": {
#             "p": {
#                 "type": "string",
#             },
#         },
#         "required": ["p"]
#     }
# }
# ```
# Example output will look like the following:
# ```json
# [{"p":"bp_or_pathway1"},
#  {"p":"bp_or_pathway2"},
#  {"p":"bp_or_pathway3"},
#  {"p":"bp_or_pathway4"},
#  {"p":"bp_or_pathway5}]
# ```
# The element `p` designates a pathway, biological process or cellular component. Place the output in a JSON code block. Do not add any comments in the JSON code block.
#
#
# No code blocks found
# ```json
# [{"p":"Renal salt reabsorption"},
#  {"p":"Sodium:potassium exchange and salt reabsorption"},
#  {"p":"Potassium transport"},
#  {"p":"Sodium transport"},
#  {"p":"Sodium:proton exchange"},
#  {"p":"Proton transport"},
#  {"p":"Bicarbonate transport"},
#  {"p":"Chloride transport"},
#  {"p":"Sodium:calcium exchange"},
#  {"p":"Glutamate transport"},
#  {"p":"Neutral amino acid transport"},
#  {"p":"Anion exchange"},
#  {"p":"Sodium:hydrogen exchange"},
#  {"p":"Sulfate transport"},
#  {"p":"Selenate transport"},
#  {"p":"Phosphate transport"},
#  {"p":"Oxoproline transport"},
#  {"p":"Gamma-aminobutyric acid import"},
#  {"p":"Arginine transport"},
#  {"p":"Oligopeptide transport"},
#  {"p":"Metal ion transport"},
#  {"p":"Amino acid transport"},
#  {"p":"Cation:chloride symporter activity"},
#  {"p":"Organic anion transport"},
#  {"p":"Sodium:sulfate symporter activity"},
#  {"p":"Sodium:proton antiporter activity"},
#  {"p":"Anion antiporter activity"},
#  {"p":"Sodium:bicarbonate symporter activity"},
#  {"p":"Sodium:amino acid symporter activity"},
#  {"p":"Sodium:phosphate symporter activity"},
#  {"p":"Sodium:proton symporter activity"},
#  {"p":"Sodium:neurotransmitter symporter activity"},
#  {"p":"Sodium:dicarboxylate symporter activity"},
#  {"p":"Anion:sodium symporter activity"},
#  {"p":"Sodium:potassium:chloride symporter activity"},
#  {"p":"Sodium:alanine symporter activity"},
#  {"p":"Sodium:solute symporter activity"},
#  {"p":"Sodium:lysine symporter activity"},
#  {"p":"Sodium:glutamate symporter activity"},
#  {"p":"Sodium:sulfate symporter activity"},
#  {"p":"Sodium:cholylglycine symporter activity"},
#  {"p":"Cation symporter activity"},
#  {"p":"Sodium:proline symporter activity"},
#  {"p":"Sodium:dicarboxylate symporter activity"},
#  {"p":"Sodium:solute symporter activity"},
#  {"p":"Sodium:arginine symporter activity"},
#  {"p":"Sodium:cystine symporter activity"},
#  {"p":"Sodium:carnosine symporter activity"},
#  {"p":"Sodium:methionine symporter activity"},
#  {"p":"Sodium:histidine symporter activity"},
#  {"p":"Sodium:glycine symporter activity"},
#  {"p":"Sodium:threonine symporter activity"},
#  {"p":"Sodium:histidine symporter activity"},
#  {"p":"Sodium:sarcosine symporter activity"},
#  {"p":"Sodium:glucuronate symporter activity"},
#  {"p":"Sodium:taurine symporter activity"},
#  {"p":"Sodium:phosphonate symporter activity"},
#  {"p":"Sodium:cyclic-nucleotide symporter activity"},
#  {"p":"Sodium:glutamine symporter activity"},
#  {"p":"Sodium:acetylcholine transporter activity"},
#  {"p":"Sodium:nucleoside symporter activity"},
#  {"p":"Sodium:adenosine transporter activity"},
#  {"p":"Sodium:inositol symporter activity"},
#  {"p":"Sodium:tetrahydrobiopterin transporter activity"},
#  {"p":"Sodium:phosphate symporter activity"},
#  {"p":"Sodium:sulfate symporter activity"},
#  {"p":"Sodium:adenosine symporter activity"},
#  {"p":"Sodium:pyruvate symporter activity"},
#  {"p":"Sodium:selenium symporter activity"},
#  {"p":"Sodium:phosphate symporter activity"},
#  {"p":"Sodium:oryzalin symporter activity"},
#  {"p":"Sodium:pyrimidine symporter activity"},
#  {"p":"Sodium:glutamate symporter activity"},
#  {"p":"Organic cation symporter activity"},
#  {"p":"Bile acid:Na+ symporter activity"},
#  {"p":"Sodium:alanine symporter activity"},
#  {"p":"Sodium:taurine symporter activity"},
#  {"p":"Sodium:cystine symporter activity"},
#  {"p":"Sodium:sulfate symporter activity"},
#  {"p":"Sodium:azimuth symporter activity"},
#  {"p":"Sodium:aspartate symporter activity"},
#  {"p":"Calcium:sodium antiporter activity"},
#  {"p":"Ethanolamine transport"},
#  {"p":"Pi transport"},
#  {"p":"Sodium:proline symporter activity"},
#  {"p":"Sodium:glycerate symporter activity"},
#  {"p":"Sodium:phosphate symporter activity"},
#  {"p":"Sodium:myo-inositol transporter activity"},
#  {"p":"Sodium:2-oxoglutarate symporter activity"},
#  {"p":"Sodium:malate symporter activity"},
#  {"p":"Sodium:inositol cotransport"},
#  {"p":"Sodium:succinate symporter activity"},
#  {"p":"Sodium:dicarboxylate symporter activity"},
#  {"p":"Bicarbonate:H+ symporter activity"},
#  {"p":"Bicarbonate transport"},
#  {"p":"Bicarbonate:chloride antiporter activity"},
#  {"p":"Sodium:hydrogen antiporter activity"},
#  {"p":"Sodium:pantothenate symporter activity"},
#  {"p":"Sodium:proline symporter activity"},
#  {"p":"Sodium:taurine symporter activity"},
#  {"p":"Sodium:valine symporter activity"},
#  {"p":"Sodium:choline symporter activity"},
#  {"p":"Sodium:alanine symporter activity"},
#  {"p":"Sodium:carnitine symporter activity"},
#  {"p":"Sodium:betaine symporter activity"},
#  {"p":"Proline transport"},
#  {"p":"Sodium:tolonium symporter activity"},
#  {"p":"Sodium:leucine symporter activity"},
#  {"p":"phthalate transport"},
#  {"p":"Sodium:betaine symporter activity"},
#  {"p":"sodium:lysine symporter activity"},
#  {"p":"Sodium:ascorbate transporter activity"},
#  {"p":"sodium:sulfate symporter activity"},
#  {"p":"sodium:hydrogen antiporter activity"},
#  {"p":"sodium:dicarboxylate symporter activity"},
#  {"p":"sodium:phosphate symporter activity"},
#  {"p":"sodium:proline symporter activity"},
#  {"p":"sodium:sugar symporter activity"},
#  {"p":"sodium:tetrahydrobiopterin transporter activity"},
#  {"p":"glucose:Na+ symporter activity"},
#  {"p":"sodium:alanine symporter activity"},
#  {"p":"sodium:taurine symporter activity"},
#  {"p":"sodium:glycine symporter activity"},
#  {"p":"sodium:histidine symporter activity"},
#  {"p":"sodium:cystine symporter activity"},
#  {"p":"sodium:arginine symporter activity"},
#  {"p":"Sulfate:proton symporter activity"},
#  {"p":"Sodium:tyrosine symporter activity"},
#  {"p":"Sodium:nitrate symporter activity"},
#  {"p":"Sodium:betaine symporter activity"},
#  {"p":"Sodium:phosphate symporter activity"},
#  {"p":"Sodium:sulfate symporter activity"},
#  {"p":"Sodium:sulfate symporter activity"},
#  {"p":"Sodium:glucose symporter activity"},
#  {"p":"Sodium:sarcosine symporter activity"},
#  {"p":"Sodium:succinate symporter activity"},
#  {"p":"Sodium:adenosine symporter activity"},
#  {"p":"L-carnitine transport"},
#  {"p":"Sodium:formate symporter activity"},
#  {"p":"Sodium:proline symporter activity"},
#  {"p":"Sodium:myo-inositol symporter activity"},
#  {"p":"Thiamine transport"},
#  {"p":"sodium:bicarbonate symporter activity"},
#  {"p":"biosynthetic process"},
#  {"p":"nicotine transport"},
#  {"p":"Regulation of glutamate import across plasma membrane"},
#  {"p":"L-carnitine transport"},
#  {"p":"thyroid hormone transport"},
#  {"p":"phosphate:sodium symporter activity"},
#  {"p":"N-acyltaurine transport"},
#  {"p":"Nucleoside:proton symporter activity"},
#  {"p":"neurotransmitter uptake"},
#  {"p":"T cell receptor complex binding"},
#  {"p":"Rac protein signal transduction"},
#  {"p":"Sodium-dependent phosphate transport"},
#  {"p":"Potassium:chloride symporter activity"},
#  {"p":"Neuromuscular junction development"},
#  {"p":"Inositol secondary active transmembrane transporter activity"},
#  {"p":"Sodium:solute symporter activity"},
#  {"p":"Histamine uptake"},
#  {"p":"Regulation of calcium ion import"},
#  {"p":"Proton:oligosaccharide symporter activity"},
#  {"p":"Purinergic receptor agonist activity"},
#  {"p":"Thyroid hormone transmembrane transporter activity"},
#  {"p":"Sodium:magnesium symporter activity"},
#  {"p":"Sulfonamide transport"},
#  {"p":"Organic acid transport"},
#  {"p":"Sodium:pantothenate symporter activity"},
#  {"p":"Sodium:sarcosine symporter activity"},
#  {"p":"Sodium:taurine symporter activity"},
#  {"p":"Caffeine transport"},
#  {"p":"Nucleoside-sodium symporter activity"},
#  {"p":"gamma-aminobutyric acid transmembrane transporter activity"},
#  {"p":"Pantothenate transport"},
#  {"p":"Sodium:sarcosine symporter activity"},
#  {"p":"Sodium:betaine symporter activity"},
#  {"p":"Sodium:sulfate symporter activity"},
#  {"p":"Sodium:cysteine symporter activity"},
#  {"p":"Sodium:methionine symporter activity"},
#  {"p":"Bile acid:sodium symporter activity"},
#  {"p":"Regulation of cystine import"},
#  {"p":"Nicotinate transport"},
#  {"p":"Phosphate transport"},
#  {"p":"Levothyroxine transport"},
#  {"p":"Regulation of proline import"},
#  {"p":"Sodium:sulfate symporter activity"},
#  {"p":"Regulation of histidine import"},
#  {"p":"Regulation of fatty acid import"},
#  {"p":"Regulation of threonine import"},
#  {"p":"Regulation of phenylalanine import"},
#  {"p":"Regulation of tyrosine import"},
#  {"p":"Regulation of ornithine import"},
#  {"p":"Regulation of serine import"},
#  {"p":"Sodium:neutral amino acid symporter activity"},
#  {"p":"Sodium:lysine symporter activity"},
#  {"p":"Sodium:cystine symporter activity"},
#  {"p":"Sodium:glucose symporter activity"},
#  {"p":"Sodium:manganese symporter activity"},
#  {"p":"Regulation of glycine import"},
#  {"p":"Regulation of glutamine import"},
#  {"p":"Regulation of asparagine import"},
#  {"p":"Sodium:alanine symporter activity"},
#  {"p":"Sodium:proline symporter activity"},
#  {"p":"Sodium:modelexon symporter activity"},
#  {"p":"Sodium:succinate symporter activity"},
#  {"p":"Sodium:surfactant symporter activity"},
#  {"p":"Sodium:inositol symporter activity"},
#  {"p":"Sodium:sulfate symporter activity"},
#  {"p":"Sodium:thyroxine symporter activity"},
#  {"p":"Sodium:nicotine symporter activity"},
#  {"p":"Sodium:chloride symporter activity"},
#  {"p":"Sodium:potassium symporter activity"},
#  {"p":"Sodium:glutamate symporter activity"},
#  {"p":"Sodium:histidine symporter activity"},
#  {"p":"Sodium:lysine symporter activity"},
#  {"p":"Sodium:sarcosine symporter activity"},
#  {"p":"Sodium:carnosine symporter activity"},
#  {"p":"Sodium:glycoside symporter activity"},
#  {"p":"Sodium:glucose symporter activity"},
#  {"p":"Sodium:galactose symporter activity"},
#  {"p":"Sodium:xylose symporter activity"},
#  {"p":"Sodium:fructose symporter activity"},
#  {"p":"Sodium:arabinose symporter activity"},
#  {"p":"Sodium:glucarate symporter activity"},
#  {"p":"Sodium:galacturonic acid symporter activity"},
#  {"p":"Sodium:xylitol symporter activity"},
#  {"p":"Sodium:lyxose symporter activity"},
#  {"p":"Sodium:ramnose symporter activity"},
#  {"p":"Sodium:arabinogalactan symporter activity"},
#  {"p":"Sodium:dextran symporter activity"},
#  {"p":"Sodium:arabinogalactan symporter activity"},
#  {"p":"Sodium:cyclodextrin symporter activity"},
#  {"p":"Sodium:beta-methylcyclodextrin symporter activity"},
#  {"p":"Sodium:chitin symporter activity"},
#  {"p":"Sodium:cholesterol symporter activity"},
#  {"p":"Sodium:prostaglandin symporter activity"},
#  {"p":"Sodium:thiadiazole symporter activity"},
#  {"p":"Sodium:flavonoid symporter activity"},
#  {"p":"Sodium:isoflavonoids symporter activity"},
#  {"p":"Sodium:anthocyanin symporter activity"},
#  {"p":"Sodium:carotenoid symporter activity"},
#  {"p":"Sodium:flavanoid symporter activity"},
#  {"p":"Sodium:flavonol symporter activity"},
#  {"p":"Sodium:flavone symporter activity"},
#  {"p":"Sodium:xanthone symporter activity"},
#  {"p":"Sodium:coumarin symporter activity"},
#  {"p":"Sodium:cinnamic acid symporter activity"},
#  {"p":"Sodium:catechin symporter activity"},
#  {"p":"Sodium:epicatechin symporter activity"},
#  {"p":"Sodium:quercetin symporter activity"},
#  {"p":"Sodium:luteolin symporter activity"},
#  {"p":"Sodium:apigenin symporter activity"},
#  {"p":"Sodium:hesperetin symporter activity"},
#  {"p":"Sodium:naringenin symporter activity"},
#  {"p":"Sodium:taxifolin symporter activity"},
#  {"p":"Sodium:silymarin symporter activity"},
#  {"p":"Sodium:cyanidin symporter activity"},
#  {"p":"Sodium:delphinidin symporter activity"},
#  {"p":"Sodium:malvidin symporter activity"},
#  {"p":"Sodium:peuma pelelae symporter activity"},
#  {"p":"Sodium:petunidin symporter activity"},
#  {"p":"Sodium:gingerol symporter activity"},
#  {"p":"Sodium:shogaol symporter activity"},
#  {"p":"Sodium:zonixine symporter activity"},
#  {"p":"Sodium:sunitinib symporter activity"},
#  {"p":"Sodium:vasopressin symporter activity"},
#  {"p":"Sodium:natrillin symporter activity"},
#  {"p":"Sodium:nocodazole symporter activity"},
#  {"p":"Sodium:taxane symporter activity"},
#  {"p":"Sodium:corinil symporter activity"},
#  {"p":"Sodium:interferon symporter activity"},
#  {"p":"Regulation of taurine import"},
#  {"p":"Regulation of carnitine import"},
#  {"p":"Regulation of betaine import"},
#  {"p":"Regulation of choline import"},
#  {"p":"Regulation of inositol import"},
#  {"p":"Regulation of glucose import"},
#  {"p":"Regulation of fructose import"},
#  {"p":"Regulation of sorbitol import"},
#  {"p":"Regulation of lactose import"},
#  {"p":"Regulation of galactose import"},
#  {"p":"Regulation of xylose import"},
#  {"p":"Regulation of arabinose import"},
#  {"p":"Regulation of ribose import"},
#  {"p":"Regulation of glucarate import"},
#  {"p":"Regulation of agarose import"},
#  {"p":"Regulation of cellulose import"},
#  {"p":"Regulation of chitin import"},
#  {"p":"Regulation of glycerol import"},
#  {"p":"Regulation of myoinositol import"},
#  {"p":"Regulation of lavender galactans import"},
#  {"p":"Regulation of dextron import"},
#  {"p":"Regulation of quercetin import"},
#  {"p":"Regulation of flavonol import"},
#  {"p":"Regulation of flavonoid import"},
#  {"p":"Regulation of anthocyanin import"},
#  {"p":"Regulation of carotenoid import"},
#  {"p":"Regulation of paracetamol import"},
#  {"p":"Regulation of acebutolol import"},
#  {"p":"Regulation of taurine import"},
#  {"p":"Regulation of L-carnitine import"},
#  {"p":"Regulation of betaine import"},
#  {"p":"pamidronate transport"},
#  {"p":"nicotinate transport"},
#  {"p":"sodium:calcium antiporter activity"},
#  {"p":"sodium:phosphate symporter activity"},
#  {"p":"lactate:Sodium symporter activity"},
#  {"p":"Purine transport"},
#  {"p":"Permease complex"},
#  {"p":"sodium:calcium antiporter activity"},
#  {"p":"Intracellular calcium activated chloride channel activity"},
#  {"p":"sodium:potassium:chloride symporter activity"},
#  {"p":"Potassium:sodium symporter activity"},
#  {"p":"Purine transport"},
#  {"p":"Sentenced to cell death by endoplasmic reticulum stress-inducing agents"},
#  {"p":"Purine transport"},
#  {"p":"Ednothelin transport"},
#  {"p":"Sodium:anion symporter activity"},
#  {"p":"Amyloid fibril formation"},
#  {"p":"Caffeine transport"},
#  {"p":"Sodium:potassium symporter activity"},
#  {"p":"Dipeptide transport"},
#  {"p":"Dipeptide transport"},
#  {"p":"Caffeine transport"},
#  {"p":"Cholesterol:ATP symporter activity"},
#  {"p":"Mammalian target of rapamycin signaling cascade"},
#  {"p":"GABA transport"},
#  {"p":"Sodium:potassium symporter activity"},
#  {"p":"L-serine:1-aminocyclopropane-1-carboxylic acid 4-aminotransferase activity"},
#  {"p":"Protein Jac-1 binding"},
#  {"p":"Reactive oxygen species metabolic process"},
#  {"p":"Dipeptide transport"},
#  {"p":"Sperm-egg recognition"},
#  {"p":"Regulation of intracellular pH"},
#  {"p":"Regulation of low carbon dioxide response"},
#  {"p":"Charidge migration of thylakoid luminal proteins"},
#  {"p":"Cell migration involved in sprouting angiogenesis"},
#  {"p":"Regulation of IRE1-mediated unfolded protein response"},
#  {"p":"Peptide transport"},
#  {"p":"Carnitine transport"},
#  {"p":"Acquired disorder of male reproductive system"},
#  {"p":"Water transport"},
#  {"p":"Proton transport"},
#  {"p":"Cholesterol transport"},
#  {"p":"Cholesterol transport"},
#  {"p":"sodium:r.prostaglandin antiporter activity"},
#  {"p":"nation:schogal antiporter activity"},
#  {"p":"sodium:species antiporter activity"},
#  {"p":"sodium:nitrin antiporter activity"},
#  {"p":"sodium:floralornate antiporter activity"},
#  {"p":"sodium:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1818/1818 [01:36<00:00, 18.92it/s]
# WikiPathway_2023_Human
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 801/801 [00:53<00:00, 15.07it/s]
# gpt-4o-2024-05-13
# KEGG_2021_Human
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 320/320 [01:08<00:00,  4.68it/s]
# Reactome_2022
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1818/1818 [02:29<00:00, 12.19it/s]
# WikiPathway_2023_Human
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 801/801 [01:17<00:00, 10.37it/s]

# %%
df = pd.DataFrame(output)
df.to_csv("llm2geneset_outputs.tsv", sep="\t", index=False)
df
# Out:
#                    model                 library  \
# 0     gpt-3.5-turbo-0125         KEGG_2021_Human
# 1     gpt-3.5-turbo-0125         KEGG_2021_Human
# 2     gpt-3.5-turbo-0125         KEGG_2021_Human
# 3     gpt-3.5-turbo-0125         KEGG_2021_Human
# 4     gpt-3.5-turbo-0125         KEGG_2021_Human
# ...                  ...                     ...
# 5873   gpt-4o-2024-05-13  WikiPathway_2023_Human
# 5874   gpt-4o-2024-05-13  WikiPathway_2023_Human
# 5875   gpt-4o-2024-05-13  WikiPathway_2023_Human
# 5876   gpt-4o-2024-05-13  WikiPathway_2023_Human
# 5877   gpt-4o-2024-05-13  WikiPathway_2023_Human
#
#                                                 gt_name  \
# 0                                      ABC transporters
# 1     AGE-RAGE signaling pathway in diabetic complic...
# 2                                AMPK signaling pathway
# 3                                Acute myeloid leukemia
# 4                                     Adherens junction
# ...                                                 ...
# 5873        Serotonin Receptor 4 6 7 And NR3C Signaling
# 5874               Toll Like Receptor Signaling Pathway
# 5875           TCA Cycle Aka Krebs Or Citric Acid Cycle
# 5876                                   Nucleotide GPCRs
# 5877             Prostaglandin Synthesis And Regulation
#
#                                     llm2geneset_name  llm2geneset_ROUGE1  \
# 0     ATP binding cassette (ABC) transporter complex            1.000000
# 1                              Inflammatory response            0.000000
# 2                             mTOR signaling pathway            0.666667
# 3                         PI3K-Akt signaling pathway            0.000000
# 4                        Cell-cell adherens junction            1.000000
# ...                                              ...                 ...
# 5873                          MAPK signaling pathway            0.125000
# 5874            Toll-like receptor signaling pathway            1.000000
# 5875            Tricarboxylic Acid Cycle (TCA Cycle)            0.500000
# 5876                    Adenosine Receptor Signaling            0.000000
# 5877                     Arachidonic acid metabolism            0.000000
#
#       llm2geneset_ROUGE2  llm2geneset_ROUGEL     llm2geneset_csim
# 0               1.000000            0.500000   0.6809030625974123
# 1               0.000000            0.000000  0.25340540819010726
# 2               0.500000            0.666667   0.6977507297222042
# 3               0.000000            0.000000   0.2536233394545665
# 4               1.000000            0.666667   0.8581968492841091
# ...                  ...                 ...                  ...
# 5873            0.000000            0.181818  0.39546705427249884
# 5874            1.000000            1.000000   0.9135843672254682
# 5875            0.285714            0.307692     0.80311084790496
# 5876            0.000000            0.000000  0.45561326162562077
# 5877            0.000000            0.000000    0.503425979627325
#
# [5878 rows x 8 columns]
